# %%
import niquests
import sys

sys.path.append("../")

# %%
from data_api.data_api import get_data_wapper, load_config, test_connect_api

config_path = "../strategy/config.json"
config = load_config(config_path)
http_proxy = config["binance"]["proxy"]["http"]
https_proxy = config["binance"]["proxy"]["https"]

# %%
proxies = {
    "http": http_proxy,
    "https": https_proxy,
}
url = "https://api.binance.com/api/v3/exchangeInfo"

r = niquests.get(url, proxies=proxies)
r
# Out:
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\niquests\adapters.py:945, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies, on_post_connection, on_upload_body, on_early_response, multiplexed)
#     944 try:
# --> 945     resp_or_promise = conn.urlopen(  # type: ignore[call-overload,misc]
#     946         method=request.method,
#     947         url=url,
#     948         body=request.body,
#     949         headers=request.headers,
#     950         redirect=False,
#     951         assert_same_host=False,
#     952         preload_content=False,
#     953         decode_content=False,
#     954         retries=self.max_retries,
#     955         timeout=timeout,
#     956         chunked=chunked,
#     957         on_post_connection=on_post_connection,
#     958         on_upload_body=on_upload_body,
#     959         on_early_response=early_response_hook
#     960         if on_early_response is not None
#     961         else None,
#     962         extension=extension,
#     963         multiplexed=multiplexed,
#     964     )
#     966     # branch for urllib3.future 2.5+ with advanced conn/multiplexing scheduler/mapper. aka. TrafficPolice.
#     967     # we are bypassing the PoolManager.request to directly invoke the concerned HttpPool, so we missed
#     968     # a required call to TrafficPolice::memorize(...).
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\connectionpool.py:1782, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, on_post_connection, on_upload_body, on_early_response, extension, multiplexed, **response_kw)
#    1780     new_e = ProtocolError("Connection aborted.", new_e)
# -> 1782 retries = retries.increment(
#    1783     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#    1784 )
#    1785 retries.sleep()
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\util\retry.py:499, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     498 if read is False or method is None or not self._is_method_retryable(method):
# --> 499     raise reraise(type(error), error, _stacktrace)
#     500 elif read is not None:
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\connectionpool.py:1690, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, on_post_connection, on_upload_body, on_early_response, extension, multiplexed, **response_kw)
#    1689 try:
# -> 1690     self._prepare_proxy(conn)
#    1691 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\connectionpool.py:2023, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    2017 conn.set_tunnel(
#    2018     scheme=tunnel_scheme,
#    2019     host=self._tunnel_host,
#    2020     port=self.port,
#    2021     headers=self.proxy_headers,
#    2022 )
# -> 2023 conn.connect()
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\connection.py:803, in HTTPSConnection.connect(self)
#     801 self._has_connected_to_proxy = True
# --> 803 self._tunnel()
#     804 # Override the host with the one we're requesting data from.
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\backend\hface.py:759, in HfaceBackend._tunnel(self)
#     753 self._protocol.submit_headers(
#     754     self._stream_id,
#     755     req_context,
#     756     True,
#     757 )
# --> 759 events = self.__exchange_until(
#     760     HeadersReceived,
#     761     receive_first=False,
#     762     event_type_collectable=(HeadersReceived,),
#     763     # special case for CONNECT
#     764     respect_end_stream_signal=False,
#     765 )
#     767 status: int | None = None
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\urllib3\backend\hface.py:1028, in HfaceBackend.__exchange_until(self, event_type, receive_first, event_type_collectable, respect_end_stream_signal, maximal_data_in_read, data_in_len_from, stream_id)
#    1026         pass
# -> 1028     raise ProtocolError(event.message)
#    1029 elif stream_related_event and isinstance(event, StreamResetReceived):
#    1030     # we want to catch MUST_USE_HTTP_1_1 or H3_VERSION_FALLBACK
#    1031     # HTTP/2 https://www.rfc-editor.org/rfc/rfc9113.html#name-error-codes
#    1032     # HTTP/3 https://www.iana.org/assignments/http3-parameters/http3-parameters.xhtml#http3-parameters-error-codes
#
# ProtocolError: None
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[39], line 7
#       1 proxies = {
#       2     "http": http_proxy,
#       3     "https": https_proxy,
#       4 }
#       5 url = "https://api.binance.com/api/v3/exchangeInfo"
# ----> 7 r = niquests.get(url, proxies=proxies)
#       8 r
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\niquests\api.py:173, in get(url, params, headers, cookies, auth, timeout, allow_redirects, proxies, verify, stream, cert, hooks, retries, **kwargs)
#     128 def get(
#     129     url: str,
#     130     params: QueryParameterType | None = None,
#    (...)
#     143     **kwargs: typing.Any,
#     144 ) -> Response:
#     145     r"""Sends a GET request.
#     146
#     147     :param url: URL for the new :class:`Request` object.
#    (...)
#     170     :return: :class:`Response <Response>` object
#     171     """
# --> 173     return request(
#     174         "GET",
#     175         url,
#     176         params=params,
#     177         headers=headers,
#     178         cookies=cookies,
#     179         auth=auth,
#     180         timeout=timeout,
#     181         allow_redirects=allow_redirects,
#     182         proxies=proxies,
#     183         verify=verify,
#     184         stream=stream,
#     185         cert=cert,
#     186         hooks=hooks,
#     187         retries=retries,
#     188         **kwargs,
#     189     )
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\niquests\api.py:108, in request(method, url, params, data, json, headers, cookies, files, auth, timeout, allow_redirects, proxies, verify, stream, cert, hooks, retries)
#     102 # By using the 'with' statement we are sure the session is closed, thus we
#     103 # avoid leaving sockets open which can trigger a ResourceWarning in some
#     104 # cases, and look like a memory leak in others.
#     105 with sessions.Session(
#     106     quic_cache_layer=_SHARED_QUIC_CACHE, retries=retries
#     107 ) as session:
# --> 108     return session.request(
#     109         method=method,
#     110         url=url,
#     111         params=params,
#     112         data=data,
#     113         headers=headers,
#     114         cookies=cookies,
#     115         files=files,
#     116         auth=auth,
#     117         timeout=timeout,
#     118         allow_redirects=allow_redirects,
#     119         proxies=proxies,
#     120         hooks=hooks,
#     121         stream=stream,
#     122         verify=verify,
#     123         cert=cert,
#     124         json=json,
#     125     )
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\niquests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\niquests\sessions.py:1260, in Session.send(self, request, **kwargs)
#    1256 start = preferred_clock()
#    1258 try:
#    1259     # Send the request
# -> 1260     r = adapter.send(request, **kwargs)
#    1261 except TypeError:
#    1262     if "requests." in str(type(adapter)):
#    1263         # this is required because some people may do an incomplete migration.
#    1264         # this will hint them appropriately.
#
# File d:\my_repo\chameleon-quant\.venv\Lib\site-packages\niquests\adapters.py:982, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies, on_post_connection, on_upload_body, on_early_response, multiplexed)
#     980     if "illegal header" in str(err).lower():
#     981         raise InvalidHeader(err, request=request)
# --> 982     raise ConnectionError(err, request=request)
#     984 except MaxRetryError as e:
#     985     if isinstance(e.reason, ConnectTimeoutError):
#     986         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: None

# %%
len(r.text)

# %%
r.text[0:1000]
